# %%
# import matplotlib.pyplot as plt
# import pandas as pd

# #ataset = pd.read_csv('')

# x1=[1,2,3]
# y1=[2,4,1]

# plt.plot(x1,y1, label='line-1')

# x2=[1,2,3]
# y2=[4,1,3]

# plt.plot(x2,y2, label='line-2')

# plt.xlabel('x-axis')
# plt.ylabel('y-axis')

# plt.title("Montly survival of mosquito")

# plt.legend()
# plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Minimum Temperature for the four Agro-ecological zones

# %%
# DAILY SURVIVAL RATE

# # Accra
# accra_data_min = pd.read_csv('Accra_vectorcapacity_Tn.csv')
# month = accra_data_min.month
# # month
# prob_survival_accra_min = accra_data_min.p
# # prob_survival_accra_min 




# # Accra
# accra_data_mean = pd.read_csv('Accra_vectorcapacity_Tm.csv')
# month = accra_data_mean.month
# prob_survival_accra_mean = accra_data_mean.p
# # prob_survival_accra_mean


# # # Accra
# accra_data_max = pd.read_csv('Accra_vectorcapacity_Tx.csv')
# month = accra_data_max.month
# prob_survival_accra_max = accra_data_max.p
# # prob_survival_accra_max





# # VECTORIAL CAPACITY

# # Accra
# accra_data_min = pd.read_csv('Accra_vectorcapacity_Tn.csv')
# month = accra_data_min.month
# vectorial_capacity_accra_min = accra_data_min.vc
# # vectorial_capacity_accra_min 



# # Accra
# accra_data_mean = pd.read_csv('Accra_vectorcapacity_Tm.csv')
# month = accra_data_mean.month
# vectorial_capacity_accra_mean = accra_data_mean.vc
# # vectorial_capacity_accra_mean


# # Accra
# accra_data_max = pd.read_csv('Accra_vectorcapacity_Tx.csv')
# month = accra_data_max.month
# vectorial_capacity_accra_max = accra_data_max.vc
# vectorial_capacity_accra_max

# %%
# # # Kumasi
# # kumasi_data_min = pd.read_csv('Kumasi_vectorcapacity_Tn.csv')
# # month = kumasi_data_min.month
# # prob_survival_kumasi_min = kumasi_data_min.p
# # # prob_survival_kumasi_min





# # # Kumasi
# kumasi_data_mean = pd.read_csv('Kumasi_vectorcapacity_Tm.csv')
# month = kumasi_data_mean.month
# prob_survival_kumasi_mean = kumasi_data_mean.p
# # prob_survival_kumasi_mean





# # Kumasi
# kumasi_data_max = pd.read_csv('Kumasi_vectorcapacity_Tx.csv')
# month = kumasi_data_max.month
# prob_survival_kumasi_max = kumasi_data_max.p
# # prob_survival_kumasi_max






# # VECTORIAL CAPACITY
# # Kumasi
# kumasi_data_min = pd.read_csv('Kumasi_vectorcapacity_Tn.csv')
# # kumasi_data_min
# month = kumasi_data_min.month
# vectorial_capacity_kumasi_min = kumasi_data_min.vc
# # # vectorial_capacity_kumasi_min





# # Kumasi
# kumasi_data_mean = pd.read_csv('Kumasi_vectorcapacity_Tm.csv')
# month = kumasi_data_mean.month
# vectorial_capacity_kumasi_mean = kumasi_data_mean.vc
# # vectorial_capacity_kumasi_mean





# # Kumasi
# kumasi_data_max = pd.read_csv('Kumasi_vectorcapacity_Tx.csv')
# month = kumasi_data_max.month
# vectorial_capacity_kumasi_max = kumasi_data_max.vc
# # vectorial_capacity_kumasi_max

# %%
# # Navrongo
# navrongo_data_min = pd.read_csv('Navrongo_vectorcapacity_Tn.csv')
# month = navrongo_data_min.month
# prob_survival_navrongo_min = navrongo_data_min.p
# # prob_survival_navrongo_min





# # Navrongo
# navrongo_data_mean = pd.read_csv('Navrongo_vectorcapacity_Tm.csv')
# month = navrongo_data_mean.month
# prob_survival_navrongo_mean = navrongo_data_mean.p
# # prob_survival_navrongo_mean




# # # Navrongo
# navrongo_data_max = pd.read_csv('Navrongo_vectorcapacity_Tx.csv')
# month = navrongo_data_mean.month
# prob_survival_navrongo_max = navrongo_data_max.p
# # prob_survival_navrongo_max





# # VECTORIAL CAPACITY

# # Navrongo
# navrongo_data_min = pd.read_csv('Navrongo_vectorcapacity_Tn.csv')
# month = navrongo_data_min.month
# vectorial_capacity_navrongo_min = navrongo_data_min.vc
# # vectorial_capacity_navrongo_min





# # Navrongo
# navrongo_data_mean = pd.read_csv('Navrongo_vectorcapacity_Tm.csv')
# month = navrongo_data_mean.month
# vectorial_capacity_navrongo_mean = navrongo_data_mean.vc
# # vectorial_capacity_navrongo_mean




# # # Navrongo
# navrongo_data_max = pd.read_csv('Navrongo_vectorcapacity_Tx.csv')
# month = navrongo_data_mean.month
# vectorial_capacity_navrongo_max = navrongo_data_max.vc
# # vectorial_capacity_navrongo_max

# %%
# # Tamale
# tamale_data_min = pd.read_csv('Tamale_vectorcapacity_Tn.csv')
# month = tamale_data_min.month
# prob_survival_tamale_min = tamale_data_min.p
# # prob_survival_tamale_min




# # # Tamale
# tamale_data_mean = pd.read_csv('Tamale_vectorcapacity_Tm.csv')
# month = tamale_data_mean.month
# prob_survival_tamale_mean = tamale_data_mean.p
# # prob_survival_tamale_mean




# # # Tamale
# tamale_data_max = pd.read_csv('Tamale_vectorcapacity_Tx.csv')
# month = tamale_data_max.month
# prob_survival_tamale_max = tamale_data_max.p
# # prob_survival_tamale_max






# # VECTORIAL CAPACITY
# # Tamale
# tamale_data_min = pd.read_csv('Tamale_vectorcapacity_Tn.csv')
# month = tamale_data_max.month
# vectorial_capacity_tamale_min = tamale_data_min.vc
# # vectorial_capacity_tamale_min




# # Tamale
# tamale_data_mean = pd.read_csv('Tamale_vectorcapacity_Tm.csv')
# month = tamale_data_max.month
# vectorial_capacity_tamale_mean = tamale_data_mean.vc
# # vectorial_capacity_tamale_mean




# # Tamale
# tamale_data_max = pd.read_csv('Tamale_vectorcapacity_Tx.csv')
# month = tamale_data_max.month
# vectorial_capacity_tamale_max = tamale_data_max.vc
# # vectorial_capacity_tamale_max

# %%
# Daily Survival


# Minimum Temperatures

# Graph of monthly survival of mosquitoes

# month = accra_data_min.month
# prob_survival_accra_min = accra_data_min.p
# prob_survival_kumasi_min = kumasi_data_min.p
# prob_survival_navrongo_min = navrongo_data_min.p
# # prob_survival_tamale_min = tamale_data_min.p
# prob_survival_tamale_min = tamale_data_min.p


# plt.plot(month, prob_survival_accra_min)
# plt.plot(month, prob_survival_kumasi_min)
# plt.plot(month, prob_survival_navrongo_min)
# plt.plot(month, prob_survival_tamale_min)
# plt.xlabel('month')
# plt.ylabel('survival probability')
# plt.title('MINIMUM TEMPERATURES')
# # plt.legend()
# plt.plot()
# plt.savefig('daily survival/minimum temperatures daily survival.png', dpi=300)


# # Mean Temperatures

# # Graph of monthly survival of mosquitoes
# month = tamale_data_min.month
# prob_survival_accra_mean = accra_data_mean.p
# prob_survival_kumasi_mean = kumasi_data_mean.p
# prob_survival_navrongo_mean = navrongo_data_mean.p
# prob_survival_tamale_mean = tamale_data_mean.p

# plt.plot(month, prob_survival_accra_mean)
# plt.plot(month, prob_survival_kumasi_mean)
# plt.plot(month, prob_survival_navrongo_mean)
# plt.plot(month, prob_survival_tamale_mean)
# plt.xlabel('month')
# plt.ylabel('survival probability')
# plt.title('MEAN TEMPERATURES')
# # plt.legend()
# plt.plot()
# plt.savefig('daily survival/mean temperatures daily survival.png', dpi=300)





# # Maximum Temperatures

# # Graph of monthly survival of mosquitoes
# month = accra_data_min.month
# prob_survival_accra_max = accra_data_max.p
# prob_survival_kumasi_max = kumasi_data_max.p
# prob_survival_navrongo_max = navrongo_data_max.p
# prob_survival_tamale_max = tamale_data_max.p

# plt.plot(month, prob_survival_accra_max)
# plt.plot(month, prob_survival_kumasi_max)
# plt.plot(month, prob_survival_navrongo_max)
# plt.plot(month, prob_survival_tamale_max)
# plt.xlabel('month')
# plt.ylabel('survival probability')
# plt.title('MAXIMUM TEMPERATURES')
# # plt.legend()
# plt.plot()
# plt.savefig('daily survival/maximum temperatures daily survival.png', dpi=300)









# VECTORIAL CAPACITY

# Daily Survival


# Minimum Temperatures

# # Graph of monthly survival of mosquitoes
# # month = accra_data_min.month
# # month = accra_data_mean.month
# month = accra_data_min.month
# vectorial_capacity_accra_min = accra_data_min.vc
# vectorial_capacity_kumasi_min = kumasi_data_min.vc
# vectorial_capacity_navrongo_min = navrongo_data_min.vc
# vectorial_capacity_tamale_min = tamale_data_min.vc

# plt.plot(month, vectorial_capacity_accra_min)
# plt.plot(month, vectorial_capacity_kumasi_min)
# plt.plot(month, vectorial_capacity_navrongo_min)
# plt.plot(month, vectorial_capacity_tamale_min)
# plt.xlabel('month')
# plt.ylabel('vectorial capacity')
# plt.title('MINIMUM TEMPERATURES')
# # plt.legend()
# plt.plot()
# plt.savefig('vectorial capacity/minimum temperatures daily survival.png', dpi=300)


#Mean Temperatures

# # Graph of monthly survival of mosquitoes
# month = accra_data_mean.month
# # prob_survival_accra_mean = accra_data_mean.p
# vectorial_capacity_accra_mean_ = accra_data_mean.vc
# vectorial_capacity_kumasi_mean = kumasi_data_mean.vc
# vectorial_capacity_navrongo_mean = navrongo_data_mean.vc
# vectorial_capacity_tamale_mean = tamale_data_mean.vc

# plt.plot(month, vectorial_capacity_accra_mean)
# plt.plot(month, vectorial_capacity_kumasi_mean)
# plt.plot(month, vectorial_capacity_navrongo_mean)
# plt.plot(month, vectorial_capacity_tamale_mean)
# plt.xlabel('month')
# plt.ylabel('vectorial capacity')
# plt.title('MEAN TEMPERATURES')
# # plt.legend(loc='lower right', prop={'size': 6})
# plt.plot()
# plt.savefig('vectorial capacity/mean temperatures daily survival.png', dpi=300)





# # Maximum Temperatures

# # Graph of monthly survival of mosquitoes
# month = accra_data_max.month
# vectorial_capacity_accra_max = accra_data_max.vc
# vectorial_capacity_kumasi_max = kumasi_data_max.vc
# vectorial_capacity_navrongo_max = navrongo_data_max.vc
# vectorial_capacity_tamale_max = tamale_data_max.vc

# plt.plot(month, vectorial_capacity_accra_max)
# plt.plot(month, vectorial_capacity_kumasi_max)
# plt.plot(month, vectorial_capacity_navrongo_max)
# plt.plot(month, vectorial_capacity_tamale_max)
# plt.xlabel('month')
# plt.ylabel('vectorial capacity')
# plt.title('MAXIMUM TEMPERATURES')
# # plt.legend(loc='upper left', prop={'size': 7})
# plt.plot()
# plt.savefig('vectorial capacity/maximum temperatures daily survival.png', dpi=300)

# %%
# temperature graphs

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


# # minimum temp 
accra_data_min = pd.read_csv('Accra_vectorcapacity_Tn.csv')
month = accra_data_min.month
min_temperature = accra_data_min.tn


plt.plot(month, min_temperature)
plt.xlabel('month')
plt.ylabel('minimum temperature')
plt.title('MONTHLY MINIMUM TEMPERATURES FOR ACCRA')
# # # plt.savefig('vectorial capacity/mean temperatures daily survival.png', dpi=300)



# # max-temp
# accra_data_max = pd.read_csv('Accra_vectorcapacity_Tx.csv')
# month = accra_data_max.month
# max_temperature = accra_data_max.tx


# plt.plot(month, max_temperature)
# plt.xlabel('month')
# plt.ylabel('maximum temperature')
# plt.title('MONTHLY MAXIMUM TEMPERATURES FOR ACCRA')
# # plt.savefig('vectorial capacity/mean temperatures daily survival.png', dpi=300)



# accra_data_max = pd.read_csv('Accra_vectorcapacity_Tx.csv')
# month = accra_data_max.month
# max_temperature = accra_data_min.tn



# plt.plot(month, max_temperature)
# plt.xlabel('month')
# plt.ylabel('maximum temperature')
# plt.title('MONTH AGAINST MAXIMUM TEMPERATURES FOR ACCRA')
# plt.plot()
# # plt.savefig('vectorial capacity/mean temperatures daily survival.png', dpi=300)
# Out:
# Text(0.5, 1.0, 'MONTHLY MINIMUM TEMPERATURES FOR ACCRA')
